# %%
import cv2 # works with images
from matplotlib import pyplot # for visualisation
import numpy as np

# %%
# load your image, 0 is for grey scale mode
img = cv2.imread('images.png', 0)

# %%
# visualisation function
def myimage(image):
 # image view
 pyplot.imshow(image)
 pyplot.show()
 # pixel view
 print('image size: ', image.shape)
 print('pixel matrix:\n', image)

# %%
# show the original image
myimage(img)
# resize the image
SIZE = 32
img = cv2.resize(img, (SIZE, SIZE)) 
# show the resized image
myimage(img)
# Out:
# image size:  (320, 320)
# pixel matrix:
#  [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [ 19  19  19 ...  19  19  19]
#  [ 19  19  19 ...  19  19  19]
#  [ 19  19  19 ...  19  19  19]]
# image size:  (32, 32)
# pixel matrix:
#  [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [243 243 243 ... 243 243 243]
#  [ 19  64   8 ...  19  18  19]
#  [ 19  19  15 ...  19  18  19]]

# %%
# steps = range(0,len(img),2)
# for i in steps:
#     print(max(img[i][i],img[i][i+1],img[i+1][i],img[i+1][i+1]))
    
max_pool_img = [[max(img[j][i],img[j][i+1],img[j+1][i],img[j+1][i+1]) for i in range(0,len(img),2)] for j in range(0,len(img),2)]

# %%
len(max_pool_img)
# Out:
# 16

# %%
len(max_pool_img[0])
# Out:
# 16

# %%
myimage(np.array(max_pool_img))
# Out:
# image size:  (16, 16)
# pixel matrix:
#  [[255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255 255   0   0   0 255 255 255 255 255 255 255 255 255 255]
#  [255 255   0 255   0 254   0 255 255 255 255 255 255 255 255 255]
#  [255 255   0   0   0   0   0 255 255 255 255 255 255 255 255 255]
#  [255 255   0 255 164 255   0 255 255 255 255 255 255 255 255 255]
#  [255 255 255  20   0  12 255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
# ...
